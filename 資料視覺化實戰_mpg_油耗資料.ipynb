# %% [markdown]
# <a href="https://colab.research.google.com/github/Tommy199665/Sensen/blob/main/%E8%B3%87%E6%96%99%E8%A6%96%E8%A6%BA%E5%8C%96%E5%AF%A6%E6%88%B0_mpg_%E6%B2%B9%E8%80%97%E8%B3%87%E6%96%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ggplot2 資料視覺化實戰 - mpg 🚗油耗資料
# https://leoluyi.tw/Yotta_Viz101/lecture-notes/R/ggplot2_intro.html#mpg-

# %% [markdown]
# 產生Colab R 程式環境: https://colab.research.google.com/notebook#create=true&language=r

# %% [markdown]
# https://ggplot2.tidyverse.org/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#install.packages("ggplot2")
library(ggplot2)
data(mpg)
?mpg
# This dataset contains a subset of the fuel economy data that the
#     EPA makes available on <https://fueleconomy.gov/>. It contains
#     only models which had a new release every year between 1999 and
#     2008 - this was used as a proxy for the popularity of the car.
mpg
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# ...

# %%
names(mpg)
# Out:
#  [1] "manufacturer" "model"        "displ"        "year"         "cyl"
#  [6] "trans"        "drv"          "cty"          "hwy"          "fl"
# [11] "class"

# %% [markdown]
# # 先看幾個變數：
# - displ - 引擎排氣公升
# - cyl
# - hwy - (油耗效率，哩/加侖)
# - cty
# - manufacturer
# - 大引擎的車子更耗油嗎？如果是的話，那有多耗油？
# - 引擎大小和油耗效率之間的關係為何？正/負相關？線性/非線性？相關程度？

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://github.com/rstudio/cheatsheets/blob/main/data-visualization-2.1.pdf

# %% [markdown]
# Cheatsheet

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1. Scatterplots

# %%
library(ggplot2)

ggplot(mpg, aes(displ, hwy, colour = class)) + 
  geom_point()
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy))
# Out:
# plot without title

# %% [markdown]
# 從圖表可歸納幾個結論：
#
# 兩變數為高度負相關 ── 大引擎 => 低效率
# 有些車是離群值

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = cty))
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = cyl, y = cty))
# Out:
# plot without title

# %% [markdown]
# ## Exercise: 用 mpg 資料畫不同的圖看看不同變數之間的相關
#
# - 畫出 scatterplot: hwy vs cyl
# - 畫出 scatterplot: class vs drv

# %%
## hwy vs cyl
ggplot(data = mpg) +
  geom_point(mapping = aes(x = hwy, y = cyl))
# Out:
# plot without title

# %%
## class vs drv
ggplot(data = mpg) +
  geom_point(mapping = aes(x = class, y = drv))
# Out:
# plot without title

# %% [markdown]
# # Aesthetic Mapping
# - 在 Grammar of Graphics 裡面最重要的概念就是 “Aesthetic Mapping”
# - 在畫圖前我們先來練習用眼睛👀看 aethetics

# %% [markdown]
# ## Exercise: 觀察 Aesthetic Mapping
# - 有哪些變數 variables
# - 分別對應到哪個 aethetic

# %% [markdown]
# 在 x-y 二維的 Scatterplot 加入第三個 aesthetic
#
# - x = displ
# - y = hwy
# - color = class (把 class 對應到點的顏色)
# - hint: ?geom_point: 查詢支援的 aesthetics

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy, color = class))
# Out:
# plot without title

# %% [markdown]
# x = displ
# y = hwy
# shape = class

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy, shape = class))
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 7. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 62 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# ## Plot Exercise
#
# 試試在 x-y 二維的 Scatterplot 加入第三個 aesthetic
#
# 把 class 對應到點的形狀

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy, shape = class))
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 7. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 62 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# ## Aesthetic Mappings 小結

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Static Aesthetic
# 有時候你可能只想要手動設定某個固定 aesthetic，這裡的設定只為了美觀， 並不會帶出多餘資料訊息。
#
# - 將 aesthetic 放在 aes() 裡面: map aesthetic 並自動建立 legend
# - 將 aesthetic 放在 aes() 之外: 手動設定某個固定 aesthetic

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy), color = "blue")
# Out:
# plot without title

# %% [markdown]
# ## Aesthetics 不只這些
# ?geom_: 各 geom 有不同支援的 aesthetics

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy))

ggplot(data = mpg) +
  geom_smooth(mapping = aes(x = displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Bar Charts

# %%
ggplot(data = mpg) +
  geom_bar(mapping = aes(x = class))
# Out:
# plot without title

# %% [markdown]
# # Geoms + Stats 實例
# bar charts, histograms: 計算每一組 bin 裡面的數目.

# %%
library(dplyr)
d <- mpg %>% 
  group_by(class) %>% 
  summarise(n = n())
d
ggplot(data = d) +
  geom_bar(mapping = aes(x = reorder(class, -n), y = n),
           stat = "identity")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#   class      n
# 1 2seater     5
# 2 compact    47
# 3 midsize    41
# 4 minivan    11
# 5 pickup     33
# 6 subcompact 35
# 7 suv        62
# plot without title

# %%
ggplot(data = mpg, aes(x = class)) +
  geom_bar() +
  geom_text(stat = "count",
            aes(label = ..count.., y =..count..),
            vjust = "bottom")
# Out:
# plot without title

# %% [markdown]
# # boxplots: plot quartiles. (看各種車型的油耗分佈)

# %%
# boxplots: plot quartiles. (看各種車型的油耗分佈)
ggplot(data = mpg) +
  geom_boxplot(mapping = aes(x = class, y = hwy))
# Out:
# plot without title

# %% [markdown]
# # Layers 圖層觀念
# 要呈現多個幾何圖形物件 (Geoms) 時要怎麼做到呢？
#
# - 一個 geom_<xxx>() 就會在圖上畫一圖層 (Layer)
# - 可一層層疊加上去
# - 每個圖層甚至可以用不同的 data，在畫進階圖表時很常用到
# - 但要注意是否有預設的 aesthetic 不小心 mapping 到該圖層

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy)) +
  geom_smooth(mapping= aes(x = displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# # Try Bar Charts
# - 填滿顏色 fill
# - (錯誤示範：不建議同一變數 mapping 多個 aes)

# %%
ggplot(data = mpg) +
  geom_bar(mapping = aes(x = class, fill = class))
# Out:
# plot without title

# %%
# geom_bar(position = ?)
# ?geom_bar
# 堆疊：position = "stack" (default)
ggplot(data = mpg) +
  geom_bar(mapping = aes(x = class, fill = manufacturer),
           position = "stack") +
  ggtitle('Position = "stack"')
# Out:
# plot without title

# %% [markdown]
# # position:
#
# - “identity” 同一位置（覆蓋住後面圖層）
# - “stack” 堆疊
# - “dodge” 併排
# - “fill” 堆疊並 scale 至 100%
# - “jitter” “抖…” 點會互相閃避
# - position = "identity"
#
# = 同一位置（覆蓋住後面圖層）

# %%
ggplot(data = mpg) +
  geom_bar(mapping = aes(x = class, fill = manufacturer),
           position = "identity", alpha = .4) +
  ggtitle('Position = "identity"')
# Out:
# plot without title

# %%
#position = "dodge"

# 併排
ggplot(data = mpg) +
  geom_bar(mapping = aes(x = class, fill = manufacturer),
           position = "dodge") +
  ggtitle('Position = "dodge"')
# Out:
# plot without title

# %%
#position = "fill"

#堆疊並 scale 至 100%
ggplot(data = mpg) +
  geom_bar(mapping = aes(x = class, fill = manufacturer),
           position = "fill") +
  ggtitle('Position = "fill"')
# Out:
# plot without title

# %% [markdown]
# # Facets: Small-Multiples
# - Too many variables!!!!
#
# - 看到剛才的車車油耗🚗，是不是覺得還是很難透過圖表理解資料？
# - 剛才畫的圖因為多了第3個變數，所以更難理解了

# %% [markdown]
# # 讓視覺化增加資訊的清晰度: facet_wrap()
#
# 畫出各車廠(manufacturer)在不同車型(class)的數量 bar chart
#
# x: class
# y: count
# fill: 多餘的 mapping，但為了強調不同車型，還是加入
# facet: manufacturer

# %%
ggplot(data = mpg) +
  geom_bar(mapping = aes(x = class, fill = class)) +
  facet_wrap( ~ manufacturer, ncol = 4) +
  scale_fill_viridis_d() +
  theme(axis.text.x = element_text(angle = 90, hjust = 1))
# Out:
# plot without title

# %%
mpg %>% 
  group_by(manufacturer, class) %>%
  tally() %>% 
  ggplot(aes(x = class, y = manufacturer, fill = n)) +
  geom_tile() +
  geom_text(aes(label = n)) +
  scale_fill_distiller(direction = 1) +
  scale_x_discrete(position = "top") +
  ggtitle("Number of car class by manufacturers")
# Out:
# plot without title
